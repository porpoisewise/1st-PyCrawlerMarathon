# %% [markdown]
# # 瀏覽器開發者工具介紹
#
#
# * 知道瀏覽器的開發者工具
# * 能夠使用瀏覽器的開發者工具觀察資料

# %% [markdown]
# ## 作業目標
#
# 利用開發者工具去尋找「 https://www.zhihu.com/explore 」和「 http://aicoin.cn 」網站的 HTTP 網址，以及他所帶的 Headers 分別是哪些，試著用 request 去發送有沒有帶 Headers 的差異。

# %% [markdown]
# ### 1. https://www.zhihu.com/explore

# %%
import requests
url = 'https://www.zhihu.com/explore'
r = requests.get(url)
r.encoding = 'utf-8'
print(r.text)

# %% [markdown]
# ### 利用查看開發者工具觀察 Headers
#
# ```
# '''
# 放上截圖
# '''
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
url = 'http://www.zhihu.com'

headers = {
    '''
    Your Code
    '''
    'authority': 'www.zhihu.com',
    'method': 'GET',
    'path': '/signin?next=%2F',
    'scheme': 'https',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7',
    'cache-control': 'max-age=0',
    'cookie': '_zap=782592d1-cfe6-4cab-bc3c-f35ef46042d8; d_c0="AFCuSIXwThCPTgizt_Jpluv5s9e2BVcWk2U=|1572955449"; _xsrf=Gu5siuxqwMcRJ2cq5RN5RGaOVLNa04Uy; q_c1=b1824adf57f14aefa05e8be99402a767|1576240811000|1576240811000; r_cap_id="YzE2ZTdmZGYwODQ1NDM2N2FlMjVkZDg5MGY5YTQyYTc=|1576240810|fb9822fe76f2eff5a3ca151434707dbc4eb8e698"; cap_id="YmYzOGIzMmFjZGYzNGFlOTg3MDEzNWQ1NjIwZDNiZjE=|1576240810|b8bd2ed8faa8736d2d56ec13de53295055f859c0"; l_cap_id="ZGZjNmMzZmQwODEzNGE5NGE4MGMyMzRiZGI4MWI2YzM=|1576240810|68c5f1db6e494d7eb1faebf289376b91a24447f2"; Hm_lvt_98beee57fd2ef70ccdd5ca52b9740c49=1576582854,1576767348,1577092962,1577093172; tgw_l7_route=302fb19f026f5b11b5e883a5cbbb5031; capsion_ticket="2|1:0|10:1577094408|14:capsion_ticket|44:MTVmODVkMGEyYjk5NDBiNzhhYzUwZTMxM2Y5ZDZhNmU=|e8a221f4f551d2fa34aff5f6eae0076fd551937d68db564df3d2aae0248c27c2"; Hm_lpvt_98beee57fd2ef70ccdd5ca52b9740c49=1577094414',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'none',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'
}

r = requests.get(url, headers=headers)

r.encoding = 'utf-8'
print(r.text[0:600])

# %% [markdown]
# ### 2. http://aicoin.cn

# %%
import requests

url = 'http://aicoin.cn/'
r = requests.get(url)
r.encoding = 'utf-8'
print(r.text)

# %% [markdown]
# ### 利用查看開發者工具觀察 Headers
#
# ```
# '''
# 放上截圖
# '''
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
url = 'http://aicoin.cn/'

headers = {
    '''
    Your Code
    '''
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'
}

r = requests.get(url, headers=headers)
print(r.text[0:600])
