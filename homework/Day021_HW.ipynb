# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例：
#
# 1. 取出今天所有的新聞
# 2. 取出現在時間兩小時內的新聞
# 3. 根據範例，取出三天前下午三點到五點的新聞

# %% [markdown]
# ## 1. 取出今天所有的新聞

# %%
'''
Your Code
'''

from selenium import webdriver
from bs4 import BeautifulSoup

browser = webdriver.Chrome(executable_path='chromedriver')

browser.get('https://www.ettoday.net/news/news-list.htm')

# %%
# 每個兩秒鐘自動往下滑

import time

for i in range(10):
    time.sleep(2)
    browser.execute_script("window.scrollTo(0,10000);")

# %% [markdown]
# ## 2. 取出現在時間兩小時內的新聞

# %%
'''
Your Code
'''

# 取得資料，丟到 BeautifulSoup 解析

import datetime

html_source = browser.page_source
soup = BeautifulSoup(html_source, "html5lib")

current_time = datetime.datetime.now() # #現在時間
for d in soup.find(class_="part_list_2").find_all('h3'):
    date = datetime.datetime.strptime(d.find(class_="date").text, "%Y/%m/%d %H:%M")
    #print(date)
    if date.hour <= current_time.hour and (date.hour >= current_time.hour-2):
        print(d.find(class_="date").text, d.find_all('a')[-1].text)
# Out:
# 2020/02/10 18:17 疫情嚴重...施孝榮霸氣宣布民歌高峰會以「視訊練團」！
# 2020/02/10 18:15 武漢肺炎影響羽球亞團賽重新抽籤　中華隊摘首牌更有利
# 2020/02/10 18:13 400萬元住新古電梯大樓　桃園房市「老三」吸北客移居
# 2020/02/10 18:13 檢測呈陰性！日女大生乘撤僑包機返國　坦言擔心周遭懷疑眼光
# 2020/02/10 18:12 「北市居家檢疫還有6人失聯趴趴走」　黃珊珊：開罰從速從嚴
# 2020/02/10 18:12 成大173名港澳生返校「居家檢疫」14天　未能返校生提供修業配套措施
# 2020/02/10 18:10 只要15分鐘！　新版武漢肺炎檢測試劑投入火神山醫院使用
# 2020/02/10 18:10 Sony也不參與2020 MWC　最新Xperia旗艦機展出採網路直播
# 2020/02/10 18:08 HBL／汪哲宇21分射翻猛牛　南湖賞高苑2連敗
# 2020/02/10 18:08 羅志祥鍾愛社區傳價跌！鄰居賠688萬出脫持有戶　百萬行情難再見
# 2020/02/10 18:08 Dior超狂情人節禮盒男女都愛！產品、色號任你選　加送香檳限量200組
# 2020/02/10 18:07 貓咪亂尿是為了報復？　4大問題先排除...你才是稱職好奴才
# 2020/02/10 18:07 桃園第六個開幕的運動中心　鄭文燦：讓運動成為一種權利
# 2020/02/10 18:05 每天提供3噸次氯酸水　桃園美隆工業衛康商貿助防疫
# 2020/02/10 18:05 阿婆灣重機犁田撞3車騎士噴飛骨折　網：幹譙阿嬤要出來罵了！
# 2020/02/10 18:04 鄧紫棋連身泳裝「大挖空」　整片白皙美背全露…網驚：太犯規
# 2020/02/10 18:04 6歲腎貓遭棄「沒人要領養」　她接回家才發現養到極品天使！
# 2020/02/10 18:04 51歲阿伯刷孩童卡搭客運...被抓包要補票　竟譙司機5字經下場曝
# 2020/02/10 18:03 奪牌路崎嶇！桃田賢斗右眼窩底骨折休養3月　醫生：他能趕上奧運
# 2020/02/10 18:02 除渣功力一流！渣男遇上這3個星座女就沒招　立馬收山改邪歸正
# ...

# %% [markdown]
# ## 3. 根據範例，取出三天前下午三點到五點的新聞

# %%
'''
Your Code
'''

url = 'https://www.ettoday.net/news/news-list-{}-{}-{}-0.htm'.format(date.year, date.month, date.day-3)

browser = webdriver.Chrome(executable_path='chromedriver')

browser.get(url)

# %%
# start from 23:59 ~ 15:00
for i in range(30):
    time.sleep(1)
    browser.execute_script("window.scrollBy(0, 10000);")

# %%
# 取得資料，丟到 BeautifulSoup 解析

html_source = browser.page_source

soup = BeautifulSoup(html_source, "html5lib")

# %%
for d in soup.find(class_="part_list_2").find_all('h3'):
    date = datetime.datetime.strptime(d.find(class_="date").text, "%Y/%m/%d %H:%M")
    if date.hour >= 15 and date.hour <= 17:
        print(d.find(class_="date").text, d.find_all('a')[-1].text)
# Out:
# 2020/02/01 17:59 入伍1年半月領1萬4　BTOB恩光善行曝光「捐款破百萬」！
# 2020/02/01 17:59 雙手佈滿紅色血絲！　隔離病房22歲護士「寫好家書」：一線需要我
# 2020/02/01 17:55 5歲就「時薪4萬」！佩佩豬13年配音員卸任　9歲小童星接班
# 2020/02/01 17:52 武漢肺炎疫情擴散！陸官方宣布「所有影視劇停止拍攝」
# 2020/02/01 17:52 男女2人「武漢返台」留假資料！7天到處跑…里長「找嘸人」氣炸
# 2020/02/01 17:45 蘋果抗疫肺炎　即日起暫時關閉大陸42家Apple Store直營店
# 2020/02/01 17:44 曾仁和澳職季後賽先發4.1局失2分　球隊輸球淘汰結束澳職
# 2020/02/01 17:44 救援的小貓全身濕狂發抖　媽怒瞪旁邊裝傻高加索：整天舔貓！
# 2020/02/01 17:41 印尼「專機武漢撤僑」　2日載回250人將隔離兩周
# 2020/02/01 17:39 哈士奇「長頸式開鎖」卻不出門　奇葩原因網笑翻：這到底什麼生物
# 2020/02/01 17:35 被逼問「漢堡呢？」阿金皺額狂挑眉　怕到手壓衛生紙不敢動
# 2020/02/01 17:28 早上瘦大腿、下午練肚子　選對減肥黃金時段，效果立馬多5倍
# 2020/02/01 17:27 朴敘俊要電話木訥告白權娜拉！《梨泰院class》第一集就有人死了
# 2020/02/01 17:26 小主人主動爬近貓貓　牠嚇到馬上落跑！網：人家什麼事都沒做耶
# 2020/02/01 17:25 農夫拼裝車停路邊　小姊妹花視線昏暗騎車猛撞1死1重傷
# 2020/02/01 17:25 打掃12坪套房　天龍妹吃驚：估價1萬2！釣出天母人「100坪2000元」網傻了
# 2020/02/01 17:25 不斷更新／鐘南山團隊建立武漢肺炎病毒模型　可預測4天後走勢
# 2020/02/01 17:23 被懷疑罹乳癌！她悄問…有愛滋「你還願意幫我治嗎」　醫回25字暖哭3萬網
# 2020/02/01 17:23 交往2年！遠距男友「不想為了愛情丟命」...放生武漢妹　網：終於找到藉口
# 2020/02/01 17:18 接收武漢肺炎病患　日本醫院「員工小孩」慘被歧視霸凌！
# ...

# %%
# 關閉瀏覽器

browser.quit();
